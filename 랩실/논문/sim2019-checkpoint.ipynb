# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %%
d1 = {0.0: 4573, 0.14: 353, 0.28: 110, 0.42: 61, 0.57: 27, 0.71: 7, 0.85: 7, 1.0: 4, 1.14: 4, 1.28: 1, 1.42: 2, 1.57: 3, 1.71: 1, 2.14: 2, 2.42: 2, 2.57: 1, 3.0: 2, 3.42: 2, 3.85: 1, 7.28: 1}

# %%
pd1 = {0.0: 0.8855538342370256, 0.14: 0.9539116963594113, 0.28: 0.9752130131680867, 0.42: 0.9870255615801704, 0.57: 0.9922540666150271, 0.71: 0.9936096049573974, 0.85: 0.9949651432997676, 1.0: 0.9957397366382649, 1.14: 0.9965143299767621, 1.28: 0.9967079783113865, 1.42: 0.9970952749806351, 1.57: 0.9976762199845081, 1.71: 0.9978698683191324, 2.14: 0.998257164988381, 2.42: 0.9986444616576297, 2.57: 0.998838109992254, 3.0: 0.9992254066615026, 3.42: 0.9996127033307513, 3.85: 0.9998063516653756, 7.28: 0.9999999999999999}

# %%
k = list(pd1.keys())
v = list(pd1.values()) + [1]
print(k, len(k))
print(v, len(v))
# Out:
# [0.0, 0.14, 0.28, 0.42, 0.57, 0.71, 0.85, 1.0, 1.14, 1.28, 1.42, 1.57, 1.71, 2.14, 2.42, 2.57, 3.0, 3.42, 3.85, 7.28] 20
# [0.8855538342370256, 0.9539116963594113, 0.9752130131680867, 0.9870255615801704, 0.9922540666150271, 0.9936096049573974, 0.9949651432997676, 0.9957397366382649, 0.9965143299767621, 0.9967079783113865, 0.9970952749806351, 0.9976762199845081, 0.9978698683191324, 0.998257164988381, 0.9986444616576297, 0.998838109992254, 0.9992254066615026, 0.9996127033307513, 0.9998063516653756, 0.9999999999999999, 1] 21

# %% [markdown]
# 예를들어 부산 1번이 전체 기간에 걸쳐 다른 부산시민 2명을 감염시켰는데 그 2명이 서로 다른날 확진되었다면, 하루에 감염시킨 사람수는 한명이다. 만약에 그 2명이 같은날 확진되었다면, 하루에 감염시킨 사람수는 2명이다.

# %%
d1
# Out:
# {0.0: 4573,
#  0.14: 353,
#  0.28: 110,
#  0.42: 61,
#  0.57: 27,
#  0.71: 7,
#  0.85: 7,
#  1.0: 4,
#  1.14: 4,
#  1.28: 1,
#  1.42: 2,
#  1.57: 3,
#  1.71: 1,
#  2.14: 2,
#  2.42: 2,
#  2.57: 1,
#  3.0: 2,
#  3.42: 2,
#  3.85: 1,
#  7.28: 1}

# %%
pd1
# Out:
# {0.0: 0.8855538342370256,
#  0.14: 0.9539116963594113,
#  0.28: 0.9752130131680867,
#  0.42: 0.9870255615801704,
#  0.57: 0.9922540666150271,
#  0.71: 0.9936096049573974,
#  0.85: 0.9949651432997676,
#  1.0: 0.9957397366382649,
#  1.14: 0.9965143299767621,
#  1.28: 0.9967079783113865,
#  1.42: 0.9970952749806351,
#  1.57: 0.9976762199845081,
#  1.71: 0.9978698683191324,
#  2.14: 0.998257164988381,
#  2.42: 0.9986444616576297,
#  2.57: 0.998838109992254,
#  3.0: 0.9992254066615026,
#  3.42: 0.9996127033307513,
#  3.85: 0.9998063516653756,
#  7.28: 0.9999999999999999}

# %%
import math
import random

# %%
def get_r(dist, prob):
    pick = 0
    for k, v in dist.items():
        if prob <= v:
            pick = k
            break
    return pick

# %%
def distributor():
    normal_dist = pd1.copy()
    # person iteration
    weekdays = ["SUN","MON","TUE","WED","THU","FRI","SAT"]
    record = []
    transfer = [1221, 1437, 1312, 1433, 1573, 2254, 1454]
    #transfer = [5023, 4482, 4431, 4464, 4701, 7394, 7977]
    ratio = [0.00134021, 0.00160825, 0.00208247, 0.00226804, 0.00238144, 0.00247423, 0.0025567]
    base = [89]
    base_ratio = 0.24
    for i in range(len(transfer)):
        week_t = math.ceil(transfer[i] * ratio[i])
        infected = base[i] * (1 + base_ratio)
        for j, p in enumerate(range(week_t)):
            p_prob = random.uniform(0, 1)
            p_r = get_r(normal_dist, p_prob)
            print(f"DAY: {i}\t TP: {j}\t INF: {p_r}")
            infected += p_r
        base.append(infected)
    print(base)
#     plt.bar(weekdays, record, align="center")

# %%
distributor()
# Out:
# DAY: 0	 TP: 0	 INF: 0.0
# DAY: 0	 TP: 1	 INF: 0.0
# DAY: 1	 TP: 0	 INF: 0.0
# DAY: 1	 TP: 1	 INF: 0.0
# DAY: 1	 TP: 2	 INF: 0.0
# DAY: 2	 TP: 0	 INF: 0.0
# DAY: 2	 TP: 1	 INF: 0.0
# DAY: 2	 TP: 2	 INF: 0.0
# DAY: 3	 TP: 0	 INF: 0.0
# DAY: 3	 TP: 1	 INF: 0.0
# DAY: 3	 TP: 2	 INF: 0.0
# DAY: 3	 TP: 3	 INF: 0.0
# DAY: 4	 TP: 0	 INF: 0.0
# DAY: 4	 TP: 1	 INF: 0.0
# DAY: 4	 TP: 2	 INF: 0.0
# DAY: 4	 TP: 3	 INF: 0.0
# DAY: 5	 TP: 0	 INF: 0.0
# DAY: 5	 TP: 1	 INF: 0.0
# DAY: 5	 TP: 2	 INF: 0.0
# DAY: 5	 TP: 3	 INF: 0.0
# DAY: 5	 TP: 4	 INF: 0.0
# DAY: 5	 TP: 5	 INF: 0.0
# DAY: 6	 TP: 0	 INF: 0.0
# DAY: 6	 TP: 1	 INF: 0.0
# DAY: 6	 TP: 2	 INF: 0.0
# DAY: 6	 TP: 3	 INF: 0.0
# [89, 110.36, 136.8464, 169.68953599999998, 210.41502463999996, 260.9146305535999, 323.5341418864639, 401.1823359392152]

# %%
dates = ['2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
       '2020-03-13', '2020-03-14']

# %%
record_19 = pd.DataFrame(columns = ['2020-03-07'] + dates)

# %%
record_20 = pd.DataFrame(columns = ['2020-03-07'] + dates)

# %%
record_19.columns
# Out:
# Index(['2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11',
#        '2020-03-12', '2020-03-13', '2020-03-14'],
#       dtype='object')

# %%
record_20.columns
# Out:
# Index(['2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11',
#        '2020-03-12', '2020-03-13', '2020-03-14'],
#       dtype='object')

# %%
def distributor_ex_19():
    normal_dist = pd1.copy()
    # person iteration
    record = []
    #transfer = [1221, 1437, 1312, 1433, 1573, 2254, 1454]
    transfer = [5023, 4482, 4431, 4464, 4701, 7394, 7977]
    ratio = [0.00134021, 0.00160825, 0.00208247, 0.00226804, 0.00238144, 0.00247423, 0.0025567]
    base = [89]
    base_ratio = 0.24
    for i in range(len(transfer)):
        week_t = math.ceil(transfer[i] * ratio[i])
        infected = base[i] * (1 + base_ratio)
        for j, p in enumerate(range(week_t)):
            p_prob = random.uniform(0, 1)
            p_r = get_r(normal_dist, p_prob)
            # print(f"DAY: {i}\t TP: {j}\t INF: {p_r}")
            infected += p_r
        base.append(infected)
    return base

def distributor_ex_20():
    normal_dist = pd1.copy()
    # person iteration
    record = []
    transfer = [1221, 1437, 1312, 1433, 1573, 2254, 1454]
    #transfer = [5023, 4482, 4431, 4464, 4701, 7394, 7977]
    ratio = [0.00134021, 0.00160825, 0.00208247, 0.00226804, 0.00238144, 0.00247423, 0.0025567]
    base = [89]
    base_ratio = 0.24
    for i in range(len(transfer)):
        week_t = math.ceil(transfer[i] * ratio[i])
        infected = base[i] * (1 + base_ratio)
        for j, p in enumerate(range(week_t)):
            p_prob = random.uniform(0, 1)
            p_r = get_r(normal_dist, p_prob)
            # print(f"DAY: {i}\t TP: {j}\t INF: {p_r}")
            infected += p_r
        base.append(infected)
    return base

# %%
for idx in range(1000):
    record_19.loc[idx] = distributor_ex_19()

# %%
for idx in range(1000):
    record_20.loc[idx] = distributor_ex_20()

# %%
record_19.head()
# Out:
#    2020-03-07  2020-03-08  2020-03-09  2020-03-10  2020-03-11  2020-03-12  \
# 0        89.0      111.06    137.9944  171.393056  212.527389  263.673963
# 1        89.0      110.64    137.3336  170.433664  211.337743  262.338802
# 2        89.0      110.36    136.8464  170.399536  211.295425  262.006327
# 3        89.0      110.36    136.8464  170.249536  211.249425  262.229287
# 4        89.0      110.64    137.3336  170.433664  211.477743  262.512402
#
#    2020-03-13  2020-03-14
# 0  327.655714  406.853085
# 1  325.860114  405.186542
# 2  325.867845  405.776128
# 3  326.294315  405.454951
# 4  325.795378  404.546269

# %%
record_20.head()
# Out:
#    2020-03-07  2020-03-08  2020-03-09  2020-03-10  2020-03-11  2020-03-12  \
# 0        89.0      110.36    136.9864  169.863136  211.050289  262.262358
# 1        89.0      110.36    136.8464  169.689536  210.415025  260.914631
# 2        89.0      110.36    137.1264  170.036736  211.415553  262.155285
# 3        89.0      110.36    136.8464  169.689536  210.415025  260.914631
# 4        89.0      110.50    137.0200  170.044800  210.855552  261.600884
#
#    2020-03-13  2020-03-14
# 0  325.485324  403.601802
# 1  323.674142  401.495936
# 2  325.072554  403.369967
# 3  323.674142  401.495936
# 4  324.525097  402.551120

# %%
rdes19 = record_19.describe()

# %%
rdes20 = record_20.describe()

# %%
rdes19 #19년 철도 데이터 시뮬레이션 수치적 통계량
# Out:
#        2020-03-07  2020-03-08   2020-03-09   2020-03-10   2020-03-11  \
# count      1000.0  1000.00000  1000.000000  1000.000000  1000.000000
# mean         89.0   110.61336   137.480676   170.841829   212.275848
# std           0.0     0.47119     0.942324     1.282400     1.771109
# min          89.0   110.36000   136.846400   169.689536   210.415025
# 25%          89.0   110.36000   137.020000   170.120064   211.233032
# 50%          89.0   110.50000   137.193600   170.475328   211.746207
# 75%          89.0   110.64000   137.580000   171.087800   212.704831
# max          89.0   117.78000   147.440800   183.246592   227.365774
#
#         2020-03-12   2020-03-13   2020-03-14
# count  1000.000000  1000.000000  1000.000000
# mean    263.631041   327.578111   406.978138
# std       2.269763     2.903091     3.701732
# min     260.914631   323.964670   402.011727
# 25%     262.238295   325.740663   404.531932
# 50%     262.942634   326.889415   406.026945
# 75%     264.331591   328.561509   408.431445
# max     281.933560   350.297614   434.509042

# %%
rdes20 #20년 철도 데이터 시뮬레이션 수치적 통계량
# Out:
#        2020-03-07   2020-03-08   2020-03-09   2020-03-10   2020-03-11  \
# count      1000.0  1000.000000  1000.000000  1000.000000  1000.000000
# mean         89.0   110.434360   137.040096   170.039230   210.998635
# std           0.0     0.244935     0.415212     0.602126     0.858719
# min          89.0   110.360000   136.846400   169.689536   210.415025
# 25%          89.0   110.360000   136.846400   169.689536   210.555025
# 50%          89.0   110.360000   136.846400   169.863136   210.770289
# 75%          89.0   110.360000   137.126400   170.120064   211.139436
# max          89.0   113.920000   141.260800   175.163392   217.695025
#
#         2020-03-12   2020-03-13   2020-03-14
# count  1000.000000  1000.000000  1000.000000
# mean    261.769127   324.804327   402.904206
# std       1.103742     1.428634     1.808395
# min     260.914631   323.534142   401.182336
# 25%     261.129895   323.954142   401.853222
# 50%     261.461558   324.427178   402.423418
# 75%     261.965334   325.064977   403.274619
# max     270.081831   335.181470   415.625023

# %%
plt.figure(dpi=300, figsize=(12, 10))

plt.hist(record_19["2020-03-08"], range=(109,118), bins=20, alpha=0.5)
plt.hist(record_20["2020-03-08"], range=(109,118), bins=20, alpha=0.5)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(['Year 2019', 'Year 2020'], fontsize=18)

plt.show()

# %%
plt.figure(dpi=300, figsize=(12, 10))

plt.hist(record_19["2020-03-14"],  bins=25, alpha=0.5)
plt.hist(record_20["2020-03-14"],  bins=25, alpha=0.5)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(['Year 2019', 'Year 2020'], fontsize=18)

plt.show()

# %%
plt.hist(record_20["2020-03-08"], range=(108,115), bins=30)
plt.show()

# %%
rdes.loc['mean'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-234541f2a534> in <module>
# ----> 1 rdes.loc['mean'].plot()
#
# NameError: name 'rdes' is not defined

# %%
plt.figure(dpi=300, figsize=(12, 10))

plt.subplot(221)
rdes.loc['min'].plot(color="green" , marker='o')
plt.title('min')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )

plt.subplot(222)
rdes.loc['mean'].plot(color="red", marker='o' )
plt.title('mean')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )

plt.subplot(223)
rdes.loc['max'].plot(color="yellow", marker='o')
plt.title('Max')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )

plt.subplot(224)
rdes.loc['min'].plot(color="green", marker='v')
rdes.loc['mean'].plot(color="red", linestyle="--", marker='^')
rdes.loc['max'].plot(color="yellow" , marker='o')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )
plt.title('Using 19 train data')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.legend()
plt.tight_layout()


plt.show()

# %%
strip = [89,0,0,0,0,0,0,0]
for i in range(7):
    strip[i+1] = strip[i] * 1.24

# %%
print(strip)

# %%
rdestrip = rdes.copy()

# %%
rdestrip.index

# %%
for idxs in rdestrip.index.tolist():
    rdestrip.loc[idxs] = rdes.loc[idxs].values - np.array(strip)

# %%
a = np.array([1,2,3])
b = np.array([1,0,1])

# %%
print(a-b)

# %%
rdestrip

# %%
plt.figure(dpi=300, figsize=(12,10))

plt.subplot(221)
rdestrip.loc['min'].plot(color="green" , marker='o')
plt.title('min')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )

plt.subplot(222)
rdestrip.loc['mean'].plot(color="red" , marker='o')
plt.title('mean')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )

plt.subplot(223)
rdestrip.loc['max'].plot(color="yellow" , marker='o')
plt.title('max')
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )

plt.subplot(224)
rdestrip.loc['min'].plot(color="green", marker='v')
rdestrip.loc['mean'].plot(color="red", linestyle="--", marker='^')
rdestrip.loc['max'].plot(color="yellow" ,marker='o')
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
plt.yticks(fontsize='medium'  )
plt.title('Using 19 train data') 
plt.xlabel('Date')
plt.ylabel('Cumulative number of confirmed')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
